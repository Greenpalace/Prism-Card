# %%
import json
import os
import re
import glob
import pathlib

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def rule(x):
    # 괄호
    a = re.compile(r'\([^)]*\)')
    # 문장 부호
    b = re.compile('[^가-힣0-9 ]')
    x = re.sub(pattern=a, repl='', string= x)
    x = re.sub(pattern=b, repl='', string= x)
    return x

# %%
def isWav(x):
     return x.endswith('.wav')
results = list(filter(isWav, file_list))

# %%
wav_list = glob.glob("/content/drive/MyDrive/data/kids/wav/**", recursive = True)
json_list = glob.glob("/content/drive/MyDrive/data/kids/json/**", recursive = True)
results_wav = list(filter(lambda x: x.endswith('.wav'), wav_list))
results_json = list(filter(lambda x: x.endswith('.json'), json_list))

# %%
cnt = 0
for audio_path, y in zip(results_wav, results_json):
    cnt +=1
    # if cnt == 100:
    #     break
    try: 
        with open(y, encoding='UTF-8') as f:
            json_data = json.load(f)
            reading = json.dumps(json_data["Transcription"]["LabelText"], ensure_ascii = False)
        reading = rule(reading)
#         with open("C:\Python\sample/train.txt", "a") as f:
#             f.write('{0}\n'.format(audio_path))
        with open("/content/drive/MyDrive/data/kids/train.txt", "a") as f:
            f.write('{0}\t{1}\n'.format(audio_path, reading))

    except:
        with open("/content/drive/MyDrive/data/kids/train.txt", "a") as f:
            f.write("------error    error--------\n")
    print(cnt == 1061552)
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# ...

# %%
from tensorflow.python.client import device_lib

# %%
device_lib.list_local_devices()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 device_lib.list_local_devices()
#
# NameError: name 'device_lib' is not defined

# %%
pip install warp-rnnt
# Out:
# ...
#   Using cached warp_rnnt-0.5.0.tar.gz (10 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   python setup.py egg_info did not run successfully.
#   exit code: 1
#
#   [7 lines of output]
#   Traceback (most recent call last):
#     File "<string>", line 2, in <module>
#     File "<pip-setuptools-caller>", line 34, in <module>
#     File "C:\Users\user\AppData\Local\Temp\pip-install-ontioaf6\warp-rnnt_938dc32a49f744ef834b0fedaaf80a20\setup.py", line 22, in <module>
#       raise Exception("CPU version is not implemented")
#   Exception: CPU version is not implemented
#   No CUDA runtime is found, using CUDA_HOME='C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v11.6'
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ...
